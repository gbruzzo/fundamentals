# %% [markdown]
# # Mean Field Variational Inference
#
# Source orchestrators: `extras/mean_field_variational_inference/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_mean_field_variational_inference`
#
# **Interactive** — Interactively explore the Mean-Field Variational Inference extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/mean_field_variational_inference/interactive_mean_field_variational_inference.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_mean_field_variational_inference`
#
# **Simulation** — Simulate the Mean-Field Variational Inference extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/mean_field_variational_inference/simulate_mean_field_variational_inference.py', run_name='__main__')

# %% [markdown]
# ## `visualize_mean_field_variational_inference`
#
# **Visualization** — Visualize the Mean-Field Variational Inference extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/mean_field_variational_inference/visualize_mean_field_variational_inference.py', run_name='__main__')
