# %% [markdown]
# # Chapter 08
#
# Source orchestrators: `chapters/chapter_08/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_learning_attention`
#
# **Animation** — Animate Chapter 8 learning and attention convergence.
#
# Raw data (after `--save`): `output/data/chapter_08/animation_learning_attention.npz`, `output/data/chapter_08/animation_learning_attention.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_08/animation_learning_attention.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_08/animation_learning_attention.gif')))

# %% [markdown]
# ## `example_8_1_learning_attention`
#
# **Example** — Example 8.1 — learning first- and second-order parameters.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_08/example_8_1_learning_attention.py', run_name='__main__')

# %% [markdown]
# ## `example_8_2_hierarchical_continuous`
#
# **Example** — Example 8.2 — hierarchical continuous model with top-down context.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_08/example_8_2_hierarchical_continuous.py', run_name='__main__')

# %% [markdown]
# ## `visualize_message_passing`
#
# **Visualization** — Visualize Chapter 8 hierarchical forward/backward message passing.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_08/visualize_message_passing.py', run_name='__main__')
