# %% [markdown]
# # Hidden State Estimation
#
# Source orchestrators: `extras/hidden_state_estimation/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_hidden_state_estimation`
#
# **Animation** — Animate the Hidden State Estimation extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/hidden_state_estimation/animation_hidden_state_estimation.npz`, `output/data/extras/hidden_state_estimation/animation_hidden_state_estimation.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/hidden_state_estimation/animation_hidden_state_estimation.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/hidden_state_estimation/animation_hidden_state_estimation.gif')))

# %% [markdown]
# ## `interactive_hidden_state_estimation`
#
# **Interactive** — Interactively explore the Hidden State Estimation extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/hidden_state_estimation/interactive_hidden_state_estimation.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_hidden_state_estimation`
#
# **Simulation** — Simulate the Hidden State Estimation extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/hidden_state_estimation/simulate_hidden_state_estimation.py', run_name='__main__')

# %% [markdown]
# ## `visualize_hidden_state_estimation`
#
# **Visualization** — Visualize the Hidden State Estimation extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/hidden_state_estimation/visualize_hidden_state_estimation.py', run_name='__main__')
