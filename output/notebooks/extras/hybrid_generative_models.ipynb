# %% [markdown]
# # Hybrid Generative Models
#
# Source orchestrators: `extras/hybrid_generative_models/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_hybrid_generative_models`
#
# **Interactive** — Interactively explore the Hybrid Generative Models extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/hybrid_generative_models/interactive_hybrid_generative_models.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_hybrid_generative_models`
#
# **Simulation** — Simulate the Hybrid Generative Models extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/hybrid_generative_models/simulate_hybrid_generative_models.py', run_name='__main__')

# %% [markdown]
# ## `visualize_hybrid_generative_models`
#
# **Visualization** — Visualize the Hybrid Generative Models extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/hybrid_generative_models/visualize_hybrid_generative_models.py', run_name='__main__')
