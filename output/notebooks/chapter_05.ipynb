# %% [markdown]
# # Chapter 05
#
# Source orchestrators: `chapters/chapter_05/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_hierarchical`
#
# **Animation** — Animation — hierarchical predictive coding converging (Chapter 5, bonus).
#
# Raw data (after `--save`): `output/data/chapter_05/animation_hierarchical.npz`, `output/data/chapter_05/animation_hierarchical.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_05/animation_hierarchical.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_05/animation_hierarchical.gif')))

# %% [markdown]
# ## `animation_recognition_descent`
#
# **Animation** — Animation — predictive-coding recognition dynamics (Chapter 5, bonus).
#
# Raw data (after `--save`): `output/data/chapter_05/animation_recognition_descent.npz`, `output/data/chapter_05/animation_recognition_descent.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_05/animation_recognition_descent.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_05/animation_recognition_descent.gif')))

# %% [markdown]
# ## `example_5_1_prediction_errors`
#
# **Example** — §5.1 — Prediction errors and the free-energy landscape (Figs. 5.1.1 / 5.1.2).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_05/example_5_1_prediction_errors.py', run_name='__main__')

# %% [markdown]
# ## `example_5_2_precision`
#
# **Example** — §5.2 — Precision balances prediction errors (Fig. 5.1.4).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_05/example_5_2_precision.py', run_name='__main__')

# %% [markdown]
# ## `example_5_3_multivariate`
#
# **Example** — §5.3 / §5.5 — Multivariate predictive coding.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_05/example_5_3_multivariate.py', run_name='__main__')

# %% [markdown]
# ## `example_5_4_recognition_dynamics`
#
# **Example** — §5.2 — Predictive-coding recognition dynamics (Algorithm 5.2.1, Fig. 5.2.3).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_05/example_5_4_recognition_dynamics.py', run_name='__main__')

# %% [markdown]
# ## `example_5_6_parameterized`
#
# **Example** — §5.6 — Parameterized multivariate predictive coding (Fig. 5.3.5).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_05/example_5_6_parameterized.py', run_name='__main__')

# %% [markdown]
# ## `example_5_7_hierarchical`
#
# **Example** — §5.4 — Hierarchical predictive coding (Example 5.7, Fig. 5.4.4).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_05/example_5_7_hierarchical.py', run_name='__main__')

# %% [markdown]
# ## `interactive_predictive_coding`
#
# **Interactive** — Chapter 5 · Interactive predictive-coding explorer (GUI / web-launchable).
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python chapters/chapter_05/interactive_predictive_coding.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.
