# %% [markdown]
# # Chapter 14
#
# Source orchestrators: `chapters/chapter_14/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `example_14_1_ergodic_density`
#
# **Example** — Example 14.1 - ergodic density and entropy bounds.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_14/example_14_1_ergodic_density.py', run_name='__main__')

# %% [markdown]
# ## `example_14_2_survival_viability`
#
# **Example** — Example 14.2 - survival, viability, and ergodic occupancy.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_14/example_14_2_survival_viability.py', run_name='__main__')

# %% [markdown]
# ## `example_14_3_entropy_vfe_bounds`
#
# **Example** — Example 14.3 - entropy and VFE-bound bridge.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_14/example_14_3_entropy_vfe_bounds.py', run_name='__main__')

# %% [markdown]
# ## `example_14_4_bayesian_mechanics`
#
# **Example** — Example 14.4 - Markov-blanket flow and Bayesian-mechanics coupling.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_14/example_14_4_bayesian_mechanics.py', run_name='__main__')
