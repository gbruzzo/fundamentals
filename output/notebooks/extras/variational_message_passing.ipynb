# %% [markdown]
# # Variational Message Passing
#
# Source orchestrators: `extras/variational_message_passing/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_variational_message_passing`
#
# **Interactive** — Interactively explore the Variational Message Passing extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/variational_message_passing/interactive_variational_message_passing.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_variational_message_passing`
#
# **Simulation** — Simulate the Variational Message Passing extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/variational_message_passing/simulate_variational_message_passing.py', run_name='__main__')

# %% [markdown]
# ## `visualize_variational_message_passing`
#
# **Visualization** — Visualize the Variational Message Passing extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/variational_message_passing/visualize_variational_message_passing.py', run_name='__main__')
