# %% [markdown]
# # Backward Smoothing
#
# Source orchestrators: `extras/backward_smoothing/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_backward_smoothing`
#
# **Animation** — Animate the Backward Smoothing extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/backward_smoothing/animation_backward_smoothing.npz`, `output/data/extras/backward_smoothing/animation_backward_smoothing.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/backward_smoothing/animation_backward_smoothing.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/backward_smoothing/animation_backward_smoothing.gif')))

# %% [markdown]
# ## `interactive_backward_smoothing`
#
# **Interactive** — Interactively explore the Backward Smoothing extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/backward_smoothing/interactive_backward_smoothing.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_backward_smoothing`
#
# **Simulation** — Simulate the Backward Smoothing extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/backward_smoothing/simulate_backward_smoothing.py', run_name='__main__')

# %% [markdown]
# ## `visualize_backward_smoothing`
#
# **Visualization** — Visualize the Backward Smoothing extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/backward_smoothing/visualize_backward_smoothing.py', run_name='__main__')
