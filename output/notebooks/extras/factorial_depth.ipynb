# %% [markdown]
# # Factorial Depth
#
# Source orchestrators: `extras/factorial_depth/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_factorial_depth`
#
# **Interactive** — Interactively explore the Factorial Depth extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/factorial_depth/interactive_factorial_depth.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_factorial_depth`
#
# **Simulation** — Simulate the Factorial Depth extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/factorial_depth/simulate_factorial_depth.py', run_name='__main__')

# %% [markdown]
# ## `visualize_factorial_depth`
#
# **Visualization** — Visualize the Factorial Depth extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/factorial_depth/visualize_factorial_depth.py', run_name='__main__')
