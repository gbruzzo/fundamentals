# %% [markdown]
# # Bayesian Linear Regression
#
# Source orchestrators: `extras/bayesian_linear_regression/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_bayesian_linear_regression`
#
# **Animation** — Animate the Bayesian Linear Regression extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/bayesian_linear_regression/animation_bayesian_linear_regression.npz`, `output/data/extras/bayesian_linear_regression/animation_bayesian_linear_regression.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/bayesian_linear_regression/animation_bayesian_linear_regression.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/bayesian_linear_regression/animation_bayesian_linear_regression.gif')))

# %% [markdown]
# ## `interactive_bayesian_linear_regression`
#
# **Interactive** — Interactively explore the Bayesian Linear Regression extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/bayesian_linear_regression/interactive_bayesian_linear_regression.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_bayesian_linear_regression`
#
# **Simulation** — Simulate the Bayesian Linear Regression extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/bayesian_linear_regression/simulate_bayesian_linear_regression.py', run_name='__main__')

# %% [markdown]
# ## `visualize_bayesian_linear_regression`
#
# **Visualization** — Visualize the Bayesian Linear Regression extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/bayesian_linear_regression/visualize_bayesian_linear_regression.py', run_name='__main__')
