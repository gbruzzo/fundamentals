# %% [markdown]
# # Ergodic Density
#
# Source orchestrators: `extras/ergodic_density/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_ergodic_density`
#
# **Animation** — Animate the Ergodic Density extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/ergodic_density/animation_ergodic_density.npz`, `output/data/extras/ergodic_density/animation_ergodic_density.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/ergodic_density/animation_ergodic_density.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/ergodic_density/animation_ergodic_density.gif')))

# %% [markdown]
# ## `interactive_ergodic_density`
#
# **Interactive** — Interactively explore the Ergodic Density extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/ergodic_density/interactive_ergodic_density.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_ergodic_density`
#
# **Simulation** — Simulate the Ergodic Density extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/ergodic_density/simulate_ergodic_density.py', run_name='__main__')

# %% [markdown]
# ## `visualize_ergodic_density`
#
# **Visualization** — Visualize the Ergodic Density extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/ergodic_density/visualize_ergodic_density.py', run_name='__main__')
