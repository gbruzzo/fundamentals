# %% [markdown]
# # Robotics Navigation
#
# Source orchestrators: `extras/robotics_navigation/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_robotics_navigation`
#
# **Animation** — Animate the Robotics Navigation extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/robotics_navigation/animation_robotics_navigation.npz`, `output/data/extras/robotics_navigation/animation_robotics_navigation.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/robotics_navigation/animation_robotics_navigation.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/robotics_navigation/animation_robotics_navigation.gif')))

# %% [markdown]
# ## `interactive_robotics_navigation`
#
# **Interactive** — Interactively explore the Robotics Navigation extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/robotics_navigation/interactive_robotics_navigation.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_robotics_navigation`
#
# **Simulation** — Simulate the Robotics Navigation extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/robotics_navigation/simulate_robotics_navigation.py', run_name='__main__')

# %% [markdown]
# ## `visualize_robotics_navigation`
#
# **Visualization** — Visualize the Robotics Navigation extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/robotics_navigation/visualize_robotics_navigation.py', run_name='__main__')
