# %% [markdown]
# # Generative Process Model
#
# Source orchestrators: `extras/generative_process_model/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_generative_process_model`
#
# **Interactive** — Interactively explore the Generative Process And Model extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/generative_process_model/interactive_generative_process_model.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_generative_process_model`
#
# **Simulation** — Simulate the Generative Process And Model extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/generative_process_model/simulate_generative_process_model.py', run_name='__main__')

# %% [markdown]
# ## `visualize_generative_process_model`
#
# **Visualization** — Visualize the Generative Process And Model extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/generative_process_model/visualize_generative_process_model.py', run_name='__main__')
