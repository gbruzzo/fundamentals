# %% [markdown]
# # Chapter 09
#
# Source orchestrators: `chapters/chapter_09/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_belief_filtering`
#
# **Animation** — Animation — dynamic POMDP belief filtering (Chapter 9 §9.2).
#
# Raw data (after `--save`): `output/data/chapter_09/animation_belief_filtering.npz`, `output/data/chapter_09/animation_belief_filtering.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_09/animation_belief_filtering.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_09/animation_belief_filtering.gif')))

# %% [markdown]
# ## `animation_efe_tradeoff`
#
# **Animation** — Animation — policy risk/ambiguity trade-off (Chapter 9 §9.6).
#
# Raw data (after `--save`): `output/data/chapter_09/animation_efe_tradeoff.npz`, `output/data/chapter_09/animation_efe_tradeoff.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'chapters/chapter_09/animation_efe_tradeoff.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/chapter_09/animation_efe_tradeoff.gif')))

# %% [markdown]
# ## `example_9_1_state_inference`
#
# **Example** — Example 9.1 — discrete hidden-state inference in a POMDP (Chapter 9 §9.1).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_09/example_9_1_state_inference.py', run_name='__main__')

# %% [markdown]
# ## `example_9_2_dynamic_filtering`
#
# **Example** — Example 9.2 — dynamic POMDP forward filtering (Chapter 9 §9.2).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_09/example_9_2_dynamic_filtering.py', run_name='__main__')

# %% [markdown]
# ## `example_9_3_discrete_vfe`
#
# **Example** — Example 9.3 — discrete variational free energy on a simplex (Chapter 9 §9.3).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_09/example_9_3_discrete_vfe.py', run_name='__main__')

# %% [markdown]
# ## `example_9_4_gridworld`
#
# **Example** — Example 9.4/9.5 — Grid World planning by expected free energy (Chapter 9, Alg. 9.5.1).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_09/example_9_4_gridworld.py', run_name='__main__')

# %% [markdown]
# ## `example_9_6_exploration_exploitation`
#
# **Example** — Example 9.6 — exploration/exploitation from EFE decomposition (Chapter 9 §9.6).

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_09/example_9_6_exploration_exploitation.py', run_name='__main__')
