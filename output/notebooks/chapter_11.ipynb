# %% [markdown]
# # Chapter 11
#
# Source orchestrators: `chapters/chapter_11/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `example_11_1_free_energy_variants`
#
# **Example** — Example 11.1 - Part III free-energy variants over policy scores.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_11/example_11_1_free_energy_variants.py', run_name='__main__')

# %% [markdown]
# ## `example_11_2_sophisticated_planning`
#
# **Example** — Example 11.2 - sophisticated planning, preferences, forgetting, and structure learning.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_11/example_11_2_sophisticated_planning.py', run_name='__main__')

# %% [markdown]
# ## `example_11_3_preference_habit_learning`
#
# **Example** — Example 11.3 - learning C/E-style preferences, habits, and path costs.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_11/example_11_3_preference_habit_learning.py', run_name='__main__')

# %% [markdown]
# ## `example_11_4_hybrid_tree_structure`
#
# **Example** — Example 11.4 - hybrid models, tree search, and structure learning.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_11/example_11_4_hybrid_tree_structure.py', run_name='__main__')
