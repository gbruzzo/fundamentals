# %% [markdown]
# # Belief Propagation
#
# Source orchestrators: `extras/belief_propagation/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_belief_propagation`
#
# **Animation** — Animate the Belief Propagation extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/belief_propagation/animation_belief_propagation.npz`, `output/data/extras/belief_propagation/animation_belief_propagation.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/belief_propagation/animation_belief_propagation.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/belief_propagation/animation_belief_propagation.gif')))

# %% [markdown]
# ## `interactive_belief_propagation`
#
# **Interactive** — Interactively explore the Belief Propagation extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/belief_propagation/interactive_belief_propagation.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_belief_propagation`
#
# **Simulation** — Simulate the Belief Propagation extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/belief_propagation/simulate_belief_propagation.py', run_name='__main__')

# %% [markdown]
# ## `visualize_belief_propagation`
#
# **Visualization** — Visualize the Belief Propagation extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/belief_propagation/visualize_belief_propagation.py', run_name='__main__')
