# %% [markdown]
# # Learning Attention
#
# Source orchestrators: `extras/learning_attention/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_learning_attention`
#
# **Animation** — Animate the Learning And Attention extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/learning_attention/animation_learning_attention.npz`, `output/data/extras/learning_attention/animation_learning_attention.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/learning_attention/animation_learning_attention.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/learning_attention/animation_learning_attention.gif')))

# %% [markdown]
# ## `interactive_learning_attention`
#
# **Interactive** — Interactively explore the Learning And Attention extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/learning_attention/interactive_learning_attention.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_learning_attention`
#
# **Simulation** — Simulate the Learning And Attention extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/learning_attention/simulate_learning_attention.py', run_name='__main__')

# %% [markdown]
# ## `visualize_learning_attention`
#
# **Visualization** — Visualize the Learning And Attention extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/learning_attention/visualize_learning_attention.py', run_name='__main__')
