# %% [markdown]
# # Generalized Filtering
#
# Source orchestrators: `extras/generalized_filtering/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_generalized_filtering`
#
# **Animation** — Animate the Generalized Filtering extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/generalized_filtering/animation_generalized_filtering.npz`, `output/data/extras/generalized_filtering/animation_generalized_filtering.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/generalized_filtering/animation_generalized_filtering.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/generalized_filtering/animation_generalized_filtering.gif')))

# %% [markdown]
# ## `interactive_generalized_filtering`
#
# **Interactive** — Interactively explore the Generalized Filtering extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/generalized_filtering/interactive_generalized_filtering.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_generalized_filtering`
#
# **Simulation** — Simulate the Generalized Filtering extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/generalized_filtering/simulate_generalized_filtering.py', run_name='__main__')

# %% [markdown]
# ## `visualize_generalized_filtering`
#
# **Visualization** — Visualize the Generalized Filtering extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/generalized_filtering/visualize_generalized_filtering.py', run_name='__main__')
