# %% [markdown]
# # Expectation Maximization
#
# Source orchestrators: `extras/expectation_maximization/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_expectation_maximization`
#
# **Animation** — Animate the Expectation Maximization extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/expectation_maximization/animation_expectation_maximization.npz`, `output/data/extras/expectation_maximization/animation_expectation_maximization.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/expectation_maximization/animation_expectation_maximization.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/expectation_maximization/animation_expectation_maximization.gif')))

# %% [markdown]
# ## `interactive_expectation_maximization`
#
# **Interactive** — Interactively explore the Expectation Maximization extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/expectation_maximization/interactive_expectation_maximization.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_expectation_maximization`
#
# **Simulation** — Simulate the Expectation Maximization extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/expectation_maximization/simulate_expectation_maximization.py', run_name='__main__')

# %% [markdown]
# ## `visualize_expectation_maximization`
#
# **Visualization** — Visualize the Expectation Maximization extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/expectation_maximization/visualize_expectation_maximization.py', run_name='__main__')
