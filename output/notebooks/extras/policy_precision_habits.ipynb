# %% [markdown]
# # Policy Precision Habits
#
# Source orchestrators: `extras/policy_precision_habits/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_policy_precision_habits`
#
# **Animation** — Animate the Policy Precision And Habits extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/policy_precision_habits/animation_policy_precision_habits.npz`, `output/data/extras/policy_precision_habits/animation_policy_precision_habits.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/policy_precision_habits/animation_policy_precision_habits.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/policy_precision_habits/animation_policy_precision_habits.gif')))

# %% [markdown]
# ## `interactive_policy_precision_habits`
#
# **Interactive** — Interactively explore the Policy Precision And Habits extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/policy_precision_habits/interactive_policy_precision_habits.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_policy_precision_habits`
#
# **Simulation** — Simulate the Policy Precision And Habits extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/policy_precision_habits/simulate_policy_precision_habits.py', run_name='__main__')

# %% [markdown]
# ## `visualize_policy_precision_habits`
#
# **Visualization** — Visualize the Policy Precision And Habits extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/policy_precision_habits/visualize_policy_precision_habits.py', run_name='__main__')
