# %% [markdown]
# # Cavi
#
# Source orchestrators: `extras/cavi/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_cavi`
#
# **Animation** — Animate the CAVI extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/cavi/animation_cavi.npz`, `output/data/extras/cavi/animation_cavi.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/cavi/animation_cavi.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/cavi/animation_cavi.gif')))

# %% [markdown]
# ## `interactive_cavi`
#
# **Interactive** — Interactively explore the CAVI extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/cavi/interactive_cavi.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_cavi`
#
# **Simulation** — Simulate the CAVI extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/cavi/simulate_cavi.py', run_name='__main__')

# %% [markdown]
# ## `visualize_cavi`
#
# **Visualization** — Visualize the CAVI extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/cavi/visualize_cavi.py', run_name='__main__')
