# %% [markdown]
# # Structure Learning
#
# Source orchestrators: `extras/structure_learning/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_structure_learning`
#
# **Interactive** — Interactively explore the Structure Learning extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/structure_learning/interactive_structure_learning.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_structure_learning`
#
# **Simulation** — Simulate the Structure Learning extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/structure_learning/simulate_structure_learning.py', run_name='__main__')

# %% [markdown]
# ## `visualize_structure_learning`
#
# **Visualization** — Visualize the Structure Learning extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/structure_learning/visualize_structure_learning.py', run_name='__main__')
