# %% [markdown]
# # Surprisal Evidence
#
# Source orchestrators: `extras/surprisal_evidence/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_surprisal_evidence`
#
# **Interactive** — Interactively explore the Surprisal And Evidence extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/surprisal_evidence/interactive_surprisal_evidence.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_surprisal_evidence`
#
# **Simulation** — Simulate the Surprisal And Evidence extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/surprisal_evidence/simulate_surprisal_evidence.py', run_name='__main__')

# %% [markdown]
# ## `visualize_surprisal_evidence`
#
# **Visualization** — Visualize the Surprisal And Evidence extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/surprisal_evidence/visualize_surprisal_evidence.py', run_name='__main__')
