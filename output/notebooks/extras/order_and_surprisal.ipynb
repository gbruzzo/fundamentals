# %% [markdown]
# # Order And Surprisal
#
# Source orchestrators: `extras/order_and_surprisal/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_order_and_surprisal`
#
# **Interactive** — Interactively explore the Order And Surprisal extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/order_and_surprisal/interactive_order_and_surprisal.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_order_and_surprisal`
#
# **Simulation** — Simulate the Order And Surprisal extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/order_and_surprisal/simulate_order_and_surprisal.py', run_name='__main__')

# %% [markdown]
# ## `visualize_order_and_surprisal`
#
# **Visualization** — Visualize the Order And Surprisal extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/order_and_surprisal/visualize_order_and_surprisal.py', run_name='__main__')
