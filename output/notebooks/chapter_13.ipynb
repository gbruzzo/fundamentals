# %% [markdown]
# # Chapter 13
#
# Source orchestrators: `chapters/chapter_13/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `example_13_1_robotics_navigation`
#
# **Example** — Example 13.1 - robotics navigation as preference satisfaction.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_13/example_13_1_robotics_navigation.py', run_name='__main__')

# %% [markdown]
# ## `example_13_2_fault_tolerant_control`
#
# **Example** — Example 13.2 - goal-directed and fault-tolerant control.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_13/example_13_2_fault_tolerant_control.py', run_name='__main__')

# %% [markdown]
# ## `example_13_3_social_robotics`
#
# **Example** — Example 13.3 - social robotics as hidden-intention inference.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_13/example_13_3_social_robotics.py', run_name='__main__')

# %% [markdown]
# ## `example_13_4_robotics_theory`
#
# **Example** — Example 13.4 - robotics theory theme landscape.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'chapters/chapter_13/example_13_4_robotics_theory.py', run_name='__main__')
