# %% [markdown]
# # Appendix Notation Model Setup
#
# Source orchestrators: `extras/appendix_notation_model_setup/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `visualize_appendix_notation_model_setup`
#
# **Visualization** — Visualize the Appendix B notation and model setup extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/appendix_notation_model_setup/visualize_appendix_notation_model_setup.py', run_name='__main__')
