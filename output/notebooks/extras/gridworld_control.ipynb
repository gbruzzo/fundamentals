# %% [markdown]
# # Gridworld Control
#
# Source orchestrators: `extras/gridworld_control/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_gridworld_control`
#
# **Animation** — Animate the Gridworld Control extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/gridworld_control/animation_gridworld_control.npz`, `output/data/extras/gridworld_control/animation_gridworld_control.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/gridworld_control/animation_gridworld_control.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/gridworld_control/animation_gridworld_control.gif')))

# %% [markdown]
# ## `interactive_gridworld_control`
#
# **Interactive** — Interactively explore the Gridworld Control extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/gridworld_control/interactive_gridworld_control.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_gridworld_control`
#
# **Simulation** — Simulate the Gridworld Control extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/gridworld_control/simulate_gridworld_control.py', run_name='__main__')

# %% [markdown]
# ## `visualize_gridworld_control`
#
# **Visualization** — Visualize the Gridworld Control extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/gridworld_control/visualize_gridworld_control.py', run_name='__main__')
