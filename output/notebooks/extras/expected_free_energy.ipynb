# %% [markdown]
# # Expected Free Energy
#
# Source orchestrators: `extras/expected_free_energy/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `interactive_expected_free_energy`
#
# **Interactive** — Interactively explore the Expected Free Energy extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/expected_free_energy/interactive_expected_free_energy.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_expected_free_energy`
#
# **Simulation** — Simulate the Expected Free Energy extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/expected_free_energy/simulate_expected_free_energy.py', run_name='__main__')

# %% [markdown]
# ## `visualize_expected_free_energy`
#
# **Visualization** — Visualize the Expected Free Energy extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/expected_free_energy/visualize_expected_free_energy.py', run_name='__main__')
