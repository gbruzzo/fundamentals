# %% [markdown]
# # Predictive Coding
#
# Source orchestrators: `extras/predictive_coding/`
#
# Textbook reading group: [https://textbook-group.activeinference.institute/](https://textbook-group.activeinference.institute/)
#
# Regenerate with `uv run python scripts/export_notebooks.py`.

# %%
from pathlib import Path
import runpy
import subprocess
import sys
import warnings

import matplotlib.pyplot as plt

REPO_ROOT = Path('/Users/4d/Documents/GitHub/projects/ongoing/instituteos/repos/fundamentals').resolve()
if str(REPO_ROOT / 'src') not in sys.path:
    sys.path.insert(0, str(REPO_ROOT / 'src'))

# %matplotlib inline
warnings.filterwarnings('default')
plt.close('all')

# %% [markdown]
# ## `animation_predictive_coding`
#
# **Animation** — Animate the Predictive Coding extras topic trajectory.
#
# Raw data (after `--save`): `output/data/extras/predictive_coding/animation_predictive_coding.npz`, `output/data/extras/predictive_coding/animation_predictive_coding.json`.

# %%
plt.close('all')
subprocess.run(
    [sys.executable, str(REPO_ROOT / 'extras/predictive_coding/animation_predictive_coding.py'), '--save'],
    check=True,
    cwd=str(REPO_ROOT),
)
from IPython.display import Image, display
display(Image(filename=str(REPO_ROOT / 'output/figures/extras/predictive_coding/animation_predictive_coding.gif')))

# %% [markdown]
# ## `interactive_predictive_coding`
#
# **Interactive** — Interactively explore the Predictive Coding extras topic.
#
# This script opens a matplotlib GUI with sliders and blocks until the window is closed. Run it from a terminal or launch it via `./run.sh --web`:
#
# ```bash
# python extras/predictive_coding/interactive_predictive_coding.py
# ```
#
# Slider-driven exploration is not executed inside this notebook kernel.

# %% [markdown]
# ## `simulate_predictive_coding`
#
# **Simulation** — Simulate the Predictive Coding extras topic parameter sweep.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/predictive_coding/simulate_predictive_coding.py', run_name='__main__')

# %% [markdown]
# ## `visualize_predictive_coding`
#
# **Visualization** — Visualize the Predictive Coding extras topic.

# %%
plt.close('all')
runpy.run_path(REPO_ROOT / 'extras/predictive_coding/visualize_predictive_coding.py', run_name='__main__')
